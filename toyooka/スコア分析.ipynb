# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("./out/result.csv", header=None)
df.columns = ["N", "K", "score"]

# %%
df.groupby(["K"]).mean()
# Out:
#        N    score
# K
# 2  27.08  1649.52
# 3  28.08   616.16
# 4  31.00   404.92
# 5  35.64   328.60
